# %%
from solve_GL import *
# Out:
# 0:  |F(x)| = 0.205133; step 1
# 1:  |F(x)| = 0.0311907; step 1
# 2:  |F(x)| = 0.00621935; step 1
# 3:  |F(x)| = 0.000888356; step 1
# 4:  |F(x)| = 0.000225409; step 1
# 5:  |F(x)| = 4.53903e-05; step 1
# 6:  |F(x)| = 8.81944e-06; step 1
# 7:  |F(x)| = 1.03732e-06; step 1
# 8:  |F(x)| = 1.41917e-07; step 1
# 9:  |F(x)| = 1.07068e-08; step 1
# 10:  |F(x)| = 1.21559e-09; step 1
# 11:  |F(x)| = 1.12583e-10; step 1
# 12:  |F(x)| = 1.08191e-11; step 1
# average Free Energy density= (-0.9108822224884456+0j)
# Angular momentum L = 2.512685718823148
# Angular momentum L_phi = 0.48861245488444227
# Angular momentum L_r = 2.0240731727085515

# %%
x1 = 3*np.abs(eta1)**2+np.abs(eta2)**2-4*np.abs(eta2)*np.abs(eta1)

# %%
plt.plot(x1)

# %%
x2 = 3*np.abs(eta1)**2+np.abs(eta2)**2

# %%
plt.plot(x2)

# %%
np.sum(x1)*h
# Out:
# 15.049222059987176

# %%
np.sum(x2)*h
# Out:
# 120.40352319796621

# %%
np.sum(x1) / np.sum(x2)
# Out:
# 0.12498988119511589

# %% [markdown]
# $\Omega_1^\pm \approx \dfrac{\hbar}{M R^2} \left( \dfrac{1}{2} \pm \dfrac{1}{8} \right)$
