# %%
from solve_GL import *
# Out:
# 0:  |F(x)| = 0.214131; step 1
# 1:  |F(x)| = 0.0318895; step 1
# 2:  |F(x)| = 0.00583001; step 1
# 3:  |F(x)| = 0.00103829; step 1
# 4:  |F(x)| = 0.000240301; step 1
# 5:  |F(x)| = 5.01983e-05; step 1
# 6:  |F(x)| = 9.80785e-06; step 1
# 7:  |F(x)| = 1.24434e-06; step 1
# 8:  |F(x)| = 1.73671e-07; step 1
# 9:  |F(x)| = 1.08089e-08; step 1
# 10:  |F(x)| = 1.45667e-09; step 1
# 11:  |F(x)| = 6.87297e-11; step 1
# 12:  |F(x)| = 1.12678e-11; step 1
# average Free Energy density= (-0.9108822283145647+0j)
# Angular momentum L = 2.512689052696065
# Angular momentum L_phi = 0.4886124580050055
# Angular momentum L_r = 2.024076594708844

# %%
x1 = 3*np.abs(eta1)**2+np.abs(eta2)**2-4*np.abs(eta2)*np.abs(eta1)

# %%
plt.plot(x1)

# %%
x2 = 3*np.abs(eta1)**2+np.abs(eta2)**2

# %%
plt.plot(x2)

# %%
np.sum(x1)*h
# Out:
# 15.049222059735264

# %%
np.sum(x2)*h
# Out:
# 120.40352319808649

# %%
integrate.trapezoid(x1, dx=h)
# Out:
# 14.658373740054003

# %%
integrate.trapezoid(x2, dx=h)
# Out:
# 120.01267487840522

# %%
integrate.trapezoid(x1, dx=h) / integrate.trapezoid(x2, dx=h)
# Out:
# 0.12214021356415575

# %% [markdown]
# $\Omega_1^\pm \approx \dfrac{\hbar}{M R^2} \left( \dfrac{1}{2} \pm 0.122 \right)$

# %%
x3 = np.abs(eta1)*np.abs(eta2)

# %%
xs = np.linspace(0, 30, 301)

# %%
plt.plot(xs, x3)
plt.plot(xs, np.tanh(xs/3))

# %%
np.log(2)/5
# Out:
# 0.13862943611198905

# %% [markdown]
# $\Omega_1^\pm \approx \dfrac{\hbar}{M R^2} \left( \dfrac{1}{2} \pm \dfrac{\ln(2)}{5} \right)$
